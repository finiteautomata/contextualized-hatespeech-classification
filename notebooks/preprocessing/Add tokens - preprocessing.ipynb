# %% [markdown]
# ## Vocabulary Analysis

# %%
# %load_ext autoreload
# %autoreload 2
import transformers
from transformers import AutoModel, AutoTokenizer

model_name = 'dccuchile/bert-base-spanish-wwm-uncased'

tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
print("Tenemos ahora ", len(tokenizer), " tokens")
# Out:
# Tenemos ahora  31002  tokens

# %%
tokenizer.tokenize("CHUPAME LA ***")
# Out:
# ['chupa', '##me', 'la', '*', '*', '*']

# %%
from transformers import BertTokenizerFast

# %%
type(tokenizer)
# Out:
# transformers.models.bert.tokenization_bert_fast.BertTokenizerFast

# %%
tokenizer.tokenize("pija")
# Out:
# ['pi', '##ja']

# %%
tokenizer.tokenize("trolo")
# Out:
# ['tro', '##lo']

# %%
tokenizer.tokenize("maricón")
# Out:
# ['maricón']

# %%
tokenizer.tokenize("marica")
# Out:
# ['marica']

# %%
tokenizer.tokenize("puto")
# Out:
# ['puto']

# %%
tokenizer.tokenize("Hacete ortear viejo trolazo")
# Out:
# ['hace', '##te', 'or', '##tear', 'viejo', 'tro', '##laz', '##o']

# %% [markdown]
# Es un problema esto. Veamos cómo agregar posiblemente estos tokens...

# %%
tokenizer.special_tokens_map
# Out:
# {'unk_token': '[UNK]',
#  'sep_token': '[SEP]',
#  'pad_token': '[PAD]',
#  'cls_token': '[CLS]',
#  'mask_token': '[MASK]'}

# %% [markdown]
# ## Training new tokenizer

# %%
from hatedetection import load_datasets

train_dataset, dev_dataset, test_dataset = load_datasets()

# %%
from hatedetection.preprocessing import preprocess_tweet

preprocess_tweet("@clarincom jajajaja #NoVuelvenMas 🤣❌❌", hashtag_token="[HASHTAG]")
# Out:
# '[USER] jaja [HASHTAG] no vuelven mas [EMOJI] cara revolviéndose de la risa [EMOJI][EMOJI] marca de cruz [EMOJI][EMOJI] marca de cruz [EMOJI]'

# %% [markdown]
# Veamos los que están más de 10 veces

# %%
from tokenizers import BertWordPieceTokenizer

new_tokenizer = BertWordPieceTokenizer(lowercase=True)
texts = [ex["text"] for ex in train_dataset]

special_tokens = [
    "[USER]",
    "[HASHTAG]",
    "[EMOJI]",
]

new_tokenizer.add_special_tokens(special_tokens)
# Out:
# 3

# %%
new_tokenizer.train_from_iterator(
    texts, min_frequency=10
)

# %%
old_tokens = set(tokenizer.get_vocab())

missing_tokens = [tok for tok in new_tokenizer.get_vocab() if tok not in old_tokens]

len(missing_tokens)
# Out:
# 2099

# %%
preprocessed_text = preprocess_tweet("@clarincom jajajaja #NoVuelvenMas 🤣❌❌", hashtag_token="[HASHTAG]")

print(preprocessed_text)
ids = new_tokenizer.encode(preprocessed_text).ids
print("Ids = ", ids)
print("Decoded = ", new_tokenizer.decode(ids))
# Out:
# [USER] jaja [HASHTAG] no vuelven mas [EMOJI] cara revolviéndose de la risa [EMOJI][EMOJI] marca de cruz [EMOJI][EMOJI] marca de cruz [EMOJI]
# Ids =  [0, 447, 1, 131, 3324, 206, 2, 172, 484, 113, 124, 272, 2, 2, 5649, 113, 4576, 2, 2, 5649, 113, 4576, 2]
# Decoded =  jaja no vuelven mas cara revolviendose de la risa marca de cruz marca de cruz

# %% [markdown]
# Ojo que el `.decode` saca todos los `[USER]`, `[HASHTAG]` y demás

# %% [markdown]
# Antes había ~2900, sacamos casi 800. Bien!

# %%
for i, tok in enumerate(sorted(missing_tokens)):
    print(f"{i+1:<4} -- {tok}")
# Out:
# 1    -- #
# 2    -- ##5n
# 3    -- ##aaa
# 4    -- ##aan
# 5    -- ##abon
# 6    -- ##acion
# 7    -- ##aj
# 8    -- ##aleza
# 9    -- ##amer
# 10   -- ##anal
# 11   -- ##anan
# 12   -- ##andose
# 13   -- ##arde
# 14   -- ##arent
# 15   -- ##arentena
# 16   -- ##arma
# 17   -- ##aroni
# 18   -- ##bacion
# 19   -- ##bajo
# 20   -- ##baron
# 21   -- ##bica
# 22   -- ##carce
# 23   -- ##cci
# 24   -- ##ccion
# 25   -- ##cciones
# 26   -- ##cepcion
# 27   -- ##cepto
# 28   -- ##cero
# 29   -- ##chando
# 30   -- ##charon
# 31   -- ##chazo
# 32   -- ##chera
# 33   -- ##chita
# 34   -- ##chner
# 35   -- ##chor
# 36   -- ##chorros
# 37   -- ##choso
# 38   -- ##chul
# 39   -- ##ciada
# 40   -- ##cian
# 41   -- ##ciando
# 42   -- ##ciaron
# 43   -- ##ciela
# 44   -- ##cien
# 45   -- ##ciendose
# 46   -- ##cog
# 47   -- ##cras
# 48   -- ##cridad
# 49   -- ##ct
# 50   -- ##cter
# 51   -- ##cto
# 52   -- ##ctor
# 53   -- ##ctora
# 54   -- ##ctores
# 55   -- ##ctos
# 56   -- ##ctu
# 57   -- ##ctura
# 58   -- ##cua
# 59   -- ##cues
# 60   -- ##cun
# 61   -- ##cuper
# 62   -- ##dable
# 63   -- ##dalla
# 64   -- ##dando
# 65   -- ##dara
# 66   -- ##daron
# 67   -- ##deces
# 68   -- ##demia
# 69   -- ##democra
# 70   -- ##dena
# 71   -- ##dental
# 72   -- ##dentes
# 73   -- ##dere
# 74   -- ##deria
# 75   -- ##deric
# 76   -- ##dian
# 77   -- ##diando
# 78   -- ##diante
# 79   -- ##dibilidad
# 80   -- ##dical
# 81   -- ##dicia
# 82   -- ##dicion
# 83   -- ##dona
# 84   -- ##doni
# 85   -- ##dono
# 86   -- ##doro
# 87   -- ##dran
# 88   -- ##dres
# 89   -- ##dria
# 90   -- ##drian
# 91   -- ##duro
# 92   -- ##eada
# 93   -- ##ean
# 94   -- ##eccion
# 95   -- ##eceria
# 96   -- ##ectar
# 97   -- ##eee
# 98   -- ##elisco
# 99   -- ##emon
# 100  -- ##enado
# 101  -- ##enar
# 102  -- ##entido
# 103  -- ##enzuela
# 104  -- ##eps
# 105  -- ##ereb
# 106  -- ##erias
# 107  -- ##ervas
# 108  -- ##esion
# 109  -- ##espera
# 110  -- ##eti
# 111  -- ##eva
# 112  -- ##fab
# 113  -- ##fasta
# 114  -- ##fff
# 115  -- ##fier
# 116  -- ##fiero
# 117  -- ##fla
# 118  -- ##fob
# 119  -- ##gacion
# 120  -- ##gera
# 121  -- ##ggan
# 122  -- ##gias
# 123  -- ##gino
# 124  -- ##gla
# 125  -- ##glaterra
# 126  -- ##gles
# 127  -- ##gob
# 128  -- ##gobierno
# 129  -- ##gona
# 130  -- ##gonia
# 131  -- ##gonzos
# 132  -- ##gote
# 133  -- ##grafia
# 134  -- ##grantes
# 135  -- ##greso
# 136  -- ##gri
# 137  -- ##guayo
# 138  -- ##guenza
# 139  -- ##guenzas
# 140  -- ##guito
# 141  -- ##halde
# 142  -- ##hhh
# 143  -- ##hii
# 144  -- ##iaste
# 145  -- ##ibel
# 146  -- ##ican
# 147  -- ##icando
# 148  -- ##icano
# 149  -- ##icanos
# 150  -- ##icaron
# 151  -- ##iccion
# 152  -- ##icciones
# 153  -- ##icop
# 154  -- ##idera
# 155  -- ##iendose
# 156  -- ##ienten
# 157  -- ##ierto
# 158  -- ##ieza
# 159  -- ##iguen
# 160  -- ##ilita
# 161  -- ##ilos
# 162  -- ##imena
# 163  -- ##inacion
# 164  -- ##inaron
# 165  -- ##inci
# 166  -- ##incido
# 167  -- ##inha
# 168  -- ##inman
# 169  -- ##iola
# 170  -- ##iria
# 171  -- ##irus
# 172  -- ##isimo
# 173  -- ##ision
# 174  -- ##isla
# 175  -- ##istes
# 176  -- ##istica
# 177  -- ##isticas
# 178  -- ##istina
# 179  -- ##itarismo
# 180  -- ##itaron
# 181  -- ##iter
# 182  -- ##itima
# 183  -- ##iw
# 184  -- ##izacion
# 185  -- ##jaj
# 186  -- ##jaja
# 187  -- ##jajaj
# 188  -- ##jajajaja
# 189  -- ##jajajajajaja
# 190  -- ##jajajajajajajaja
# 191  -- ##jajajajajajajajajajajajajajajaja
# 192  -- ##jajajajajajajajajajajajajajajajajajajajajajajajajajajajajajajaja
# 193  -- ##jajas
# 194  -- ##jis
# 195  -- ##jitos
# 196  -- ##jj
# 197  -- ##jja
# 198  -- ##jjaja
# 199  -- ##jua
# 200  -- ##juajua
# 201  -- ##jud
# 202  -- ##lacion
# 203  -- ##lario
# 204  -- ##lce
# 205  -- ##leb
# 206  -- ##lexion
# 207  -- ##leza
# 208  -- ##lican
# 209  -- ##licar
# 210  -- ##lici
# 211  -- ##ligo
# 212  -- ##liquen
# 213  -- ##lismo
# 214  -- ##lita
# 215  -- ##lito
# 216  -- ##llos
# 217  -- ##loque
# 218  -- ##lub
# 219  -- ##lusion
# 220  -- ##macion
# 221  -- ##maron
# 222  -- ##maste
# 223  -- ##mbien
# 224  -- ##mbo
# 225  -- ##mbr
# 226  -- ##mbra
# 227  -- ##mena
# 228  -- ##mencia
# 229  -- ##mendi
# 230  -- ##meno
# 231  -- ##menos
# 232  -- ##mera
# 233  -- ##mial
# 234  -- ##mias
# 235  -- ##mici
# 236  -- ##mido
# 237  -- ##miendo
# 238  -- ##millon
# 239  -- ##minacion
# 240  -- ##minado
# 241  -- ##minan
# 242  -- ##minando
# 243  -- ##minar
# 244  -- ##mios
# 245  -- ##mision
# 246  -- ##mite
# 247  -- ##mmm
# 248  -- ##mn
# 249  -- ##mocra
# 250  -- ##monio
# 251  -- ##moso
# 252  -- ##mosos
# 253  -- ##mpan
# 254  -- ##mpita
# 255  -- ##mpo
# 256  -- ##mue
# 257  -- ##neces
# 258  -- ##neristas
# 259  -- ##nn
# 260  -- ##oba
# 261  -- ##obar
# 262  -- ##obre
# 263  -- ##ocu
# 264  -- ##ole
# 265  -- ##ologa
# 266  -- ##ologica
# 267  -- ##ologico
# 268  -- ##ologicos
# 269  -- ##ologo
# 270  -- ##ologos
# 271  -- ##oner
# 272  -- ##onico
# 273  -- ##ooo
# 274  -- ##oos
# 275  -- ##opa
# 276  -- ##orable
# 277  -- ##orada
# 278  -- ##orado
# 279  -- ##ormal
# 280  -- ##osi
# 281  -- ##osicion
# 282  -- ##osito
# 283  -- ##osta
# 284  -- ##ow
# 285  -- ##pacion
# 286  -- ##pando
# 287  -- ##paron
# 288  -- ##petu
# 289  -- ##pez
# 290  -- ##piar
# 291  -- ##pita
# 292  -- ##pitales
# 293  -- ##pite
# 294  -- ##pob
# 295  -- ##ponsab
# 296  -- ##ports
# 297  -- ##put
# 298  -- ##puta
# 299  -- ##ql
# 300  -- ##qlp
# 301  -- ##qtp
# 302  -- ##racho
# 303  -- ##racion
# 304  -- ##ralde
# 305  -- ##rede
# 306  -- ##resa
# 307  -- ##resenta
# 308  -- ##resion
# 309  -- ##reta
# 310  -- ##rible
# 311  -- ##roga
# 312  -- ##roque
# 313  -- ##rote
# 314  -- ##rov
# 315  -- ##rr
# 316  -- ##sab
# 317  -- ##sb
# 318  -- ##secu
# 319  -- ##sj
# 320  -- ##tacion
# 321  -- ##tazos
# 322  -- ##teces
# 323  -- ##tent
# 324  -- ##tere
# 325  -- ##terra
# 326  -- ##terres
# 327  -- ##tf
# 328  -- ##ticano
# 329  -- ##tici
# 330  -- ##titucion
# 331  -- ##titucional
# 332  -- ##todos
# 333  -- ##tracion
# 334  -- ##tumb
# 335  -- ##tumbre
# 336  -- ##ucion
# 337  -- ##udar
# 338  -- ##udia
# 339  -- ##udio
# 340  -- ##uele
# 341  -- ##uera
# 342  -- ##ulan
# 343  -- ##upuesto
# 344  -- ##urbano
# 345  -- ##uron
# 346  -- ##urralde
# 347  -- ##usion
# 348  -- ##ustea
# 349  -- ##uuu
# 350  -- ##uza
# 351  -- ##vadas
# 352  -- ##vante
# 353  -- ##vencia
# 354  -- ##verso
# 355  -- ##veza
# 356  -- ##viada
# 357  -- ##vian
# 358  -- ##vibles
# 359  -- ##vidad
# 360  -- ##vimiento
# 361  -- ##virus
# 362  -- ##ws
# 363  -- ##xn
# 364  -- ##xnxn
# 365  -- ##xs
# 366  -- ##yy
# 367  -- ##yyy
# 368  -- ##zacion
# 369  -- '
# 370  -- 14
# 371  -- 16
# 372  -- 17
# 373  -- 18
# 374  -- 194
# 375  -- 2021
# 376  -- 2023
# 377  -- 24
# 378  -- 26
# 379  -- 28
# 380  -- 40
# 381  -- 400
# 382  -- 41
# 383  -- 45
# 384  -- 48
# 385  -- 4ta
# 386  -- 60
# 387  -- 65
# 388  -- 70
# 389  -- 75
# 390  -- 80
# 391  -- [EMOJI]
# 392  -- [HASHTAG]
# 393  -- [USER]
# 394  -- ^
# 395  -- `
# 396  -- aaa
# 397  -- aaaa
# 398  -- abortar
# 399  -- abortera
# 400  -- aborteras
# 401  -- abortos
# 402  -- abrazando
# 403  -- abrio
# 404  -- aburri
# 405  -- aburrimiento
# 406  -- abusa
# 407  -- abusador
# 408  -- acci
# 409  -- aclaro
# 410  -- acomo
# 411  -- acomodada
# 412  -- acompan
# 413  -- acordas
# 414  -- acuerdan
# 415  -- acusan
# 416  -- admin
# 417  -- adoc
# 418  -- adoctrina
# 419  -- adon
# 420  -- aerolin
# 421  -- aerolineas
# 422  -- afan
# 423  -- afana
# 424  -- afano
# 425  -- afr
# 426  -- agarren
# 427  -- agarro
# 428  -- agita
# 429  -- agotada
# 430  -- agrade
# 431  -- agradez
# 432  -- agredir
# 433  -- agresion
# 434  -- aguante
# 435  -- ahhh
# 436  -- aisla
# 437  -- aislan
# 438  -- aislen
# 439  -- aja
# 440  -- ajaja
# 441  -- alberso
# 442  -- alberti
# 443  -- albertitere
# 444  -- albertito
# 445  -- alcahue
# 446  -- alegria
# 447  -- aleman
# 448  -- alfons
# 449  -- alfonsin
# 450  -- aliment
# 451  -- aliviada
# 452  -- alos
# 453  -- alrede
# 454  -- alverso
# 455  -- alzada
# 456  -- amba
# 457  -- ambulan
# 458  -- ambulancias
# 459  -- ami
# 460  -- amontona
# 461  -- analfab
# 462  -- analisis
# 463  -- andate
# 464  -- anibal
# 465  -- anticuarentena
# 466  -- antidemocra
# 467  -- antidemocratico
# 468  -- antropologa
# 469  -- aparecio
# 470  -- apelli
# 471  -- aplaud
# 472  -- aplauden
# 473  -- aplaudiendo
# 474  -- aplaudo
# 475  -- aporto
# 476  -- aprendan
# 477  -- aprendio
# 478  -- aprobacion
# 479  -- aprove
# 480  -- aprovechan
# 481  -- aprovechen
# 482  -- argenta
# 483  -- argentos
# 484  -- argenzuela
# 485  -- armaron
# 486  -- artic
# 487  -- asesinas
# 488  -- asociacion
# 489  -- asomb
# 490  -- asombrada
# 491  -- asquerosos
# 492  -- asu
# 493  -- asumio
# 494  -- asun
# 495  -- ataco
# 496  -- atencion
# 497  -- atien
# 498  -- atomica
# 499  -- atorrante
# 500  -- atorrantes
# 501  -- atropel
# 502  -- audios
# 503  -- auh
# 504  -- aument
# 505  -- avion
# 506  -- avise
# 507  -- avisen
# 508  -- avisenle
# 509  -- axel
# 510  -- aysa
# 511  -- ayyy
# 512  -- baez
# 513  -- bajon
# 514  -- bana
# 515  -- banan
# 516  -- bancan
# 517  -- bancate
# 518  -- bano
# 519  -- baradel
# 520  -- barbaridad
# 521  -- barbaridades
# 522  -- barbaro
# 523  -- barbi
# 524  -- barbijo
# 525  -- barbijos
# 526  -- barde
# 527  -- bardo
# 528  -- bastaaa
# 529  -- basuras
# 530  -- baul
# 531  -- berni
# 532  -- berreta
# 533  -- besti
# 534  -- beto
# 535  -- bibl
# 536  -- biceps
# 537  -- biden
# 538  -- biologia
# 539  -- biologica
# 540  -- bizar
# 541  -- boicot
# 542  -- boli
# 543  -- bolitas
# 544  -- bolivian
# 545  -- bolivianos
# 546  -- bolson
# 547  -- bolsonaro
# 548  -- bolsos
# 549  -- bolu
# 550  -- bolud
# 551  -- boluda
# 552  -- boludas
# 553  -- bolude
# 554  -- boludeces
# 555  -- boludez
# 556  -- boludo
# 557  -- boludos
# 558  -- bonaer
# 559  -- bosta
# 560  -- boton
# 561  -- boudo
# 562  -- boudou
# 563  -- brandoni
# 564  -- brieva
# 565  -- brindando
# 566  -- bronca
# 567  -- brutos
# 568  -- bubonica
# 569  -- buch
# 570  -- bueee
# 571  -- bueh
# 572  -- buenisimo
# 573  -- bullrich
# 574  -- burros
# 575  -- buscate
# 576  -- bye
# 577  -- c5n
# 578  -- cabreada
# 579  -- cacer
# 580  -- cadaver
# 581  -- cadaveres
# 582  -- cafiero
# 583  -- cag
# 584  -- caga
# 585  -- cagada
# 586  -- cagadas
# 587  -- cagamos
# 588  -- cagan
# 589  -- cagando
# 590  -- cagaron
# 591  -- cagarse
# 592  -- cagon
# 593  -- cagones
# 594  -- cague
# 595  -- caguen
# 596  -- cahn
# 597  -- caida
# 598  -- caigan
# 599  -- caje
# 600  -- cajon
# 601  -- calavera
# 602  -- callese
# 603  -- camara
# 604  -- camaras
# 605  -- camb
# 606  -- cambiemos
# 607  -- camioneros
# 608  -- campito
# 609  -- campora
# 610  -- canosa
# 611  -- cansa
# 612  -- caradura
# 613  -- caraduras
# 614  -- carceles
# 615  -- careta
# 616  -- carrio
# 617  -- carton
# 618  -- castracion
# 619  -- catastro
# 620  -- catastrofe
# 621  -- cater
# 622  -- cato
# 623  -- caval
# 624  -- cavallo
# 625  -- cavern
# 626  -- cbu
# 627  -- cdo
# 628  -- ceja
# 629  -- celeb
# 630  -- ceno
# 631  -- cereb
# 632  -- cerra
# 633  -- cfk
# 634  -- chancho
# 635  -- chanchos
# 636  -- chanta
# 637  -- charlatan
# 638  -- chauuu
# 639  -- chavista
# 640  -- chetos
# 641  -- chila
# 642  -- chiques
# 643  -- chon
# 644  -- chongo
# 645  -- choreo
# 646  -- chori
# 647  -- choripan
# 648  -- chorra
# 649  -- chorras
# 650  -- chorro
# 651  -- chorros
# 652  -- chota
# 653  -- choto
# 654  -- chupame
# 655  -- chupan
# 656  -- chupando
# 657  -- chupe
# 658  -- chupen
# 659  -- cientif
# 660  -- cientifica
# 661  -- cientifico
# 662  -- cientificos
# 663  -- cinica
# 664  -- cinico
# 665  -- cinicos
# 666  -- cinismo
# 667  -- cinthia
# 668  -- cipa
# 669  -- circulacion
# 670  -- circulando
# 671  -- circulo
# 672  -- clarin
# 673  -- clarinete
# 674  -- clasico
# 675  -- clinica
# 676  -- cloa
# 677  -- cloacas
# 678  -- cob
# 679  -- cobar
# 680  -- cobrando
# 681  -- cobren
# 682  -- codigo
# 683  -- coima
# 684  -- coincido
# 685  -- colab
# 686  -- colmo
# 687  -- colomb
# 688  -- coment
# 689  -- comentan
# 690  -- comenzo
# 691  -- comerse
# 692  -- comet
# 693  -- comio
# 694  -- comision
# 695  -- compan
# 696  -- companero
# 697  -- companeros
# 698  -- compania
# 699  -- complice
# 700  -- complices
# 701  -- comunicacion
# 702  -- concent
# 703  -- conch
# 704  -- conchita
# 705  -- condicion
# 706  -- confeti
# 707  -- confia
# 708  -- confian
# 709  -- congourbano
# 710  -- consi
# 711  -- constitucion
# 712  -- construccion
# 713  -- consu
# 714  -- contagi
# 715  -- contagia
# 716  -- contagiado
# 717  -- contagiados
# 718  -- contagian
# 719  -- contagiar
# 720  -- contagiaron
# 721  -- contagiarse
# 722  -- contagiaste
# 723  -- contagie
# 724  -- contagien
# 725  -- contagio
# 726  -- contagios
# 727  -- conurbano
# 728  -- convi
# 729  -- convirtio
# 730  -- copar
# 731  -- copartici
# 732  -- corchazo
# 733  -- cordoba
# 734  -- coronavirus
# 735  -- corp
# 736  -- corrupcion
# 737  -- corrupta
# 738  -- cose
# 739  -- coso
# 740  -- covid
# 741  -- covid19
# 742  -- credito
# 743  -- creerle
# 744  -- crei
# 745  -- creible
# 746  -- criminaly
# 747  -- criti
# 748  -- critican
# 749  -- criticas
# 750  -- cronica
# 751  -- cues
# 752  -- cuidan
# 753  -- cuidarnos
# 754  -- cuidarse
# 755  -- cuidate
# 756  -- cuiden
# 757  -- culia
# 758  -- culpas
# 759  -- cumpli
# 760  -- cupo
# 761  -- curi
# 762  -- curro
# 763  -- dadi
# 764  -- dady
# 765  -- dandole
# 766  -- dano
# 767  -- daria
# 768  -- ddhh
# 769  -- deberian
# 770  -- debia
# 771  -- debio
# 772  -- decadas
# 773  -- decadente
# 774  -- decia
# 775  -- decian
# 776  -- decidio
# 777  -- decile
# 778  -- decime
# 779  -- decision
# 780  -- declaracion
# 781  -- defendio
# 782  -- definicion
# 783  -- degenera
# 784  -- degenerado
# 785  -- degenerados
# 786  -- dejate
# 787  -- dejenlo
# 788  -- dejense
# 789  -- delia
# 790  -- delicu
# 791  -- delinku
# 792  -- delinkuentes
# 793  -- delinquir
# 794  -- delir
# 795  -- delirante
# 796  -- deliver
# 797  -- delivery
# 798  -- demago
# 799  -- demagogia
# 800  -- democratica
# 801  -- democratico
# 802  -- dengue
# 803  -- denuncio
# 804  -- depresion
# 805  -- dere
# 806  -- derru
# 807  -- derrumb
# 808  -- desagra
# 809  -- desaho
# 810  -- desahogo
# 811  -- desaprobacion
# 812  -- descara
# 813  -- descargo
# 814  -- descereb
# 815  -- descerebrada
# 816  -- descerebrado
# 817  -- descerebrados
# 818  -- descubrio
# 819  -- desespera
# 820  -- desinfor
# 821  -- desinforma
# 822  -- desnu
# 823  -- desnutri
# 824  -- desocu
# 825  -- desparra
# 826  -- desprecia
# 827  -- desqui
# 828  -- destruccion
# 829  -- destruyen
# 830  -- desu
# 831  -- desubica
# 832  -- desubicada
# 833  -- desubicado
# 834  -- dete
# 835  -- detras
# 836  -- devalu
# 837  -- devolucion
# 838  -- devolve
# 839  -- devuelvan
# 840  -- dialogo
# 841  -- dicie
# 842  -- dictadores
# 843  -- dictaduras
# 844  -- diganle
# 845  -- dign
# 846  -- diji
# 847  -- dip
# 848  -- dira
# 849  -- diran
# 850  -- direccion
# 851  -- diria
# 852  -- discri
# 853  -- discriminacion
# 854  -- discriminan
# 855  -- discriminar
# 856  -- distanciamiento
# 857  -- dnu
# 858  -- dolar
# 859  -- doma
# 860  -- domador
# 861  -- domes
# 862  -- domicili
# 863  -- domiciliaria
# 864  -- donacion
# 865  -- donda
# 866  -- dorso
# 867  -- dsp
# 868  -- duena
# 869  -- dueno
# 870  -- duenos
# 871  -- duggan
# 872  -- duhalde
# 873  -- econo
# 874  -- economia
# 875  -- economica
# 876  -- economicamente
# 877  -- economico
# 878  -- economicos
# 879  -- ect
# 880  -- educacion
# 881  -- educada
# 882  -- efici
# 883  -- egoista
# 884  -- ehhh
# 885  -- eleccion
# 886  -- electr
# 887  -- elia
# 888  -- eligio
# 889  -- embaja
# 890  -- emoji
# 891  -- empana
# 892  -- empanadas
# 893  -- empatia
# 894  -- empeza
# 895  -- empezo
# 896  -- empie
# 897  -- empodera
# 898  -- encabe
# 899  -- encierro
# 900  -- encog
# 901  -- encogida
# 902  -- encogido
# 903  -- encontras
# 904  -- encontro
# 905  -- ene
# 906  -- enemi
# 907  -- ener
# 908  -- energu
# 909  -- enfada
# 910  -- enfermar
# 911  -- enfermeros
# 912  -- engano
# 913  -- enojan
# 914  -- ensenar
# 915  -- enserio
# 916  -- ensob
# 917  -- ensu
# 918  -- entendes
# 919  -- entendi
# 920  -- entendieron
# 921  -- entendio
# 922  -- entiendan
# 923  -- entrev
# 924  -- epoca
# 925  -- escanda
# 926  -- escandalo
# 927  -- escapo
# 928  -- escra
# 929  -- escribio
# 930  -- esi
# 931  -- espana
# 932  -- espanto
# 933  -- espert
# 934  -- espiona
# 935  -- espirit
# 936  -- esplen
# 937  -- estara
# 938  -- estaran
# 939  -- estaria
# 940  -- estariamos
# 941  -- estarian
# 942  -- esten
# 943  -- estrate
# 944  -- estupi
# 945  -- estupida
# 946  -- estupidos
# 947  -- estuv
# 948  -- etica
# 949  -- evas
# 950  -- exagera
# 951  -- excla
# 952  -- exclamacion
# 953  -- excus
# 954  -- exi
# 955  -- exito
# 956  -- exo
# 957  -- explici
# 958  -- expresion
# 959  -- expu
# 960  -- expul
# 961  -- extincion
# 962  -- extinguir
# 963  -- extorsion
# 964  -- extr
# 965  -- extrana
# 966  -- extranar
# 967  -- extrano
# 968  -- extraterres
# 969  -- ezeiza
# 970  -- fabiola
# 971  -- facho
# 972  -- fachos
# 973  -- factu
# 974  -- facun
# 975  -- facundo
# 976  -- fake
# 977  -- falopa
# 978  -- falto
# 979  -- fana
# 980  -- fanaticos
# 981  -- fascis
# 982  -- fascistas
# 983  -- feinman
# 984  -- feinmann
# 985  -- femici
# 986  -- femina
# 987  -- feminaz
# 988  -- feminazis
# 989  -- feminismo
# 990  -- feministas
# 991  -- fernan
# 992  -- fernandez
# 993  -- festeja
# 994  -- festejan
# 995  -- festejando
# 996  -- festejar
# 997  -- feuda
# 998  -- feudal
# 999  -- ficcion
# 1000 -- fies
# 1001 -- fijate
# 1002 -- firmo
# 1003 -- fisico
# 1004 -- flaca
# 1005 -- flavio
# 1006 -- flexion
# 1007 -- flexionado
# 1008 -- flia
# 1009 -- fogon
# 1010 -- foment
# 1011 -- formosa
# 1012 -- forro
# 1013 -- forros
# 1014 -- fortunas
# 1015 -- fracasados
# 1016 -- frederic
# 1017 -- frun
# 1018 -- fruncido
# 1019 -- frustracion
# 1020 -- fugo
# 1021 -- funcionaria
# 1022 -- fusila
# 1023 -- futu
# 1024 -- gaga
# 1025 -- garca
# 1026 -- garcas
# 1027 -- garcha
# 1028 -- gastan
# 1029 -- generacion
# 1030 -- generaron
# 1031 -- genero
# 1032 -- generos
# 1033 -- genet
# 1034 -- genia
# 1035 -- genios
# 1036 -- genoci
# 1037 -- genocida
# 1038 -- genocidas
# 1039 -- gent
# 1040 -- geria
# 1041 -- ggg
# 1042 -- gila
# 1043 -- gilada
# 1044 -- gildo
# 1045 -- giles
# 1046 -- gines
# 1047 -- gob
# 1048 -- goberna
# 1049 -- gobernadora
# 1050 -- gobernando
# 1051 -- gobernaron
# 1052 -- gobiern
# 1053 -- gobierna
# 1054 -- gobiernan
# 1055 -- gobiernen
# 1056 -- gollan
# 1057 -- golp
# 1058 -- golpista
# 1059 -- golpistas
# 1060 -- goo
# 1061 -- gordita
# 1062 -- gordito
# 1063 -- goril
# 1064 -- gorilas
# 1065 -- grabo
# 1066 -- grabois
# 1067 -- gremial
# 1068 -- gremios
# 1069 -- grin
# 1070 -- grogui
# 1071 -- gron
# 1072 -- groncha
# 1073 -- grup
# 1074 -- guerri
# 1075 -- guinando
# 1076 -- guita
# 1077 -- habian
# 1078 -- habit
# 1079 -- habra
# 1080 -- habran
# 1081 -- habria
# 1082 -- hacelo
# 1083 -- hacete
# 1084 -- hacian
# 1085 -- haciendose
# 1086 -- haganse
# 1087 -- haran
# 1088 -- haria
# 1089 -- hartos
# 1090 -- hdmp
# 1091 -- hdp
# 1092 -- hdps
# 1093 -- hdr
# 1094 -- hdrmp
# 1095 -- hdrp
# 1096 -- hebe
# 1097 -- hela
# 1098 -- heladera
# 1099 -- helicop
# 1100 -- helicoptero
# 1101 -- heroe
# 1102 -- higien
# 1103 -- hipocres
# 1104 -- hipocresia
# 1105 -- hipocri
# 1106 -- hipocrita
# 1107 -- hipocritas
# 1108 -- hisopa
# 1109 -- hisopado
# 1110 -- hister
# 1111 -- homb
# 1112 -- homena
# 1113 -- homofob
# 1114 -- hubies
# 1115 -- hueca
# 1116 -- huevadas
# 1117 -- humildes
# 1118 -- identif
# 1119 -- ideolog
# 1120 -- ideologia
# 1121 -- idioteces
# 1122 -- idola
# 1123 -- idolo
# 1124 -- idon
# 1125 -- ife
# 1126 -- ignorantes
# 1127 -- ilici
# 1128 -- ilu
# 1129 -- imaginan
# 1130 -- imaginate
# 1131 -- imbeci
# 1132 -- imbecil
# 1133 -- imbeciles
# 1134 -- importo
# 1135 -- imposi
# 1136 -- impresenta
# 1137 -- impresentable
# 1138 -- impresentables
# 1139 -- improv
# 1140 -- improvisa
# 1141 -- impues
# 1142 -- impun
# 1143 -- impune
# 1144 -- impunes
# 1145 -- inadi
# 1146 -- inclusivo
# 1147 -- incoher
# 1148 -- incomp
# 1149 -- incompet
# 1150 -- incump
# 1151 -- indefen
# 1152 -- indemnizacion
# 1153 -- indice
# 1154 -- indigentes
# 1155 -- indigna
# 1156 -- indignante
# 1157 -- inefici
# 1158 -- inep
# 1159 -- inepto
# 1160 -- ineptos
# 1161 -- infectadura
# 1162 -- infecto
# 1163 -- infectolo
# 1164 -- inflacion
# 1165 -- influen
# 1166 -- infob
# 1167 -- infoba
# 1168 -- infobae
# 1169 -- infor
# 1170 -- informacion
# 1171 -- informen
# 1172 -- infrado
# 1173 -- infuma
# 1174 -- infumable
# 1175 -- inhumano
# 1176 -- inmi
# 1177 -- inmoral
# 1178 -- inmorales
# 1179 -- inmunda
# 1180 -- inmundicia
# 1181 -- inmundo
# 1182 -- inmundos
# 1183 -- inoper
# 1184 -- inoperante
# 1185 -- inoperantes
# 1186 -- inserv
# 1187 -- inservible
# 1188 -- inservibles
# 1189 -- insfran
# 1190 -- inso
# 1191 -- insolito
# 1192 -- insultar
# 1193 -- inta
# 1194 -- intele
# 1195 -- intelectu
# 1196 -- intencion
# 1197 -- interrogacion
# 1198 -- inti
# 1199 -- inun
# 1200 -- inuti
# 1201 -- inutiles
# 1202 -- inutilidad
# 1203 -- inva
# 1204 -- inventan
# 1205 -- investigacion
# 1206 -- investiguen
# 1207 -- invia
# 1208 -- inviable
# 1209 -- iph
# 1210 -- iphone
# 1211 -- iria
# 1212 -- ironia
# 1213 -- irrecuper
# 1214 -- irresponsab
# 1215 -- irresponsabilidad
# 1216 -- irresponsables
# 1217 -- ishii
# 1218 -- jaaa
# 1219 -- jaj
# 1220 -- jaja
# 1221 -- jajaj
# 1222 -- jajaja
# 1223 -- jajajaja
# 1224 -- jajajajaja
# 1225 -- jajajajajajajajaja
# 1226 -- jajajajajajajajajaja
# 1227 -- jajajajajajajajajaja6
# 1228 -- jajja
# 1229 -- jamas
# 1230 -- jeje
# 1231 -- jimena
# 1232 -- jjaja
# 1233 -- jodanse
# 1234 -- jode
# 1235 -- jodeme
# 1236 -- joden
# 1237 -- jodete
# 1238 -- jovenes
# 1239 -- jua
# 1240 -- juaaa
# 1241 -- juanita
# 1242 -- jubila
# 1243 -- jubilacion
# 1244 -- jubilaciones
# 1245 -- jubilado
# 1246 -- jubilados
# 1247 -- judio
# 1248 -- judios
# 1249 -- jueza
# 1250 -- juga
# 1251 -- juju
# 1252 -- jujuy
# 1253 -- juntan
# 1254 -- junten
# 1255 -- justif
# 1256 -- jx
# 1257 -- jxc
# 1258 -- kerner
# 1259 -- kich
# 1260 -- kici
# 1261 -- kicillo
# 1262 -- kicillof
# 1263 -- kilombo
# 1264 -- kios
# 1265 -- kirchner
# 1266 -- kirchnerismo
# 1267 -- kirchnerista
# 1268 -- kirchneristas
# 1269 -- kk
# 1270 -- klar
# 1271 -- klarin
# 1272 -- korrup
# 1273 -- korrupto
# 1274 -- korruptos
# 1275 -- kristina
# 1276 -- kuk
# 1277 -- kuka
# 1278 -- kukas
# 1279 -- kumpa
# 1280 -- labu
# 1281 -- labur
# 1282 -- labura
# 1283 -- laburan
# 1284 -- laburando
# 1285 -- laburante
# 1286 -- laburantes
# 1287 -- laburar
# 1288 -- laburen
# 1289 -- laburo
# 1290 -- lacra
# 1291 -- lacras
# 1292 -- ladr
# 1293 -- ladri
# 1294 -- ladron
# 1295 -- ladrona
# 1296 -- lagri
# 1297 -- lak
# 1298 -- lakra
# 1299 -- lakras
# 1300 -- lame
# 1301 -- lamen
# 1302 -- lanata
# 1303 -- largan
# 1304 -- largaron
# 1305 -- larreta
# 1306 -- larroque
# 1307 -- latam
# 1308 -- latinoamer
# 1309 -- latinoamerica
# 1310 -- lc
# 1311 -- lcd
# 1312 -- lean
# 1313 -- lease
# 1314 -- lechon
# 1315 -- leen
# 1316 -- legalizar
# 1317 -- legitima
# 1318 -- lei
# 1319 -- lesb
# 1320 -- leu
# 1321 -- leuco
# 1322 -- levantadas
# 1323 -- leyo
# 1324 -- liberacion
# 1325 -- liberan
# 1326 -- liberaron
# 1327 -- liberen
# 1328 -- libero
# 1329 -- libertadora
# 1330 -- lilita
# 1331 -- limit
# 1332 -- limites
# 1333 -- llamate
# 1334 -- llenan
# 1335 -- llenarse
# 1336 -- llevate
# 1337 -- lloran
# 1338 -- lob
# 1339 -- lobby
# 1340 -- logica
# 1341 -- logico
# 1342 -- lopez
# 1343 -- lora
# 1344 -- loustea
# 1345 -- lousteau
# 1346 -- lpm
# 1347 -- lpmqlp
# 1348 -- machir
# 1349 -- machirulo
# 1350 -- machismo
# 1351 -- machista
# 1352 -- macr
# 1353 -- macri
# 1354 -- macrismo
# 1355 -- macrista
# 1356 -- macristas
# 1357 -- mafios
# 1358 -- mafiosa
# 1359 -- mafioso
# 1360 -- mafiosos
# 1361 -- magneto
# 1362 -- magnetto
# 1363 -- maledu
# 1364 -- malena
# 1365 -- malpar
# 1366 -- malvin
# 1367 -- mamadera
# 1368 -- mamar
# 1369 -- mamarra
# 1370 -- mamarracho
# 1371 -- mamarrachos
# 1372 -- mamer
# 1373 -- mamerto
# 1374 -- mamita
# 1375 -- mamu
# 1376 -- manana
# 1377 -- mandamos
# 1378 -- manden
# 1379 -- manejan
# 1380 -- manifestacion
# 1381 -- manifestarse
# 1382 -- manipu
# 1383 -- manipula
# 1384 -- mansion
# 1385 -- mapuche
# 1386 -- mapuches
# 1387 -- maradona
# 1388 -- maravil
# 1389 -- maricas
# 1390 -- marmo
# 1391 -- marmota
# 1392 -- mascarilla
# 1393 -- maxima
# 1394 -- maximo
# 1395 -- mayoria
# 1396 -- mayra
# 1397 -- mediatico
# 1398 -- medica
# 1399 -- medicos
# 1400 -- mediocre
# 1401 -- mediocres
# 1402 -- mediocridad
# 1403 -- meme
# 1404 -- menem
# 1405 -- mengol
# 1406 -- mengolini
# 1407 -- mentiros
# 1408 -- mentirosos
# 1409 -- merca
# 1410 -- mercenario
# 1411 -- merda
# 1412 -- mere
# 1413 -- merecemos
# 1414 -- merito
# 1415 -- meritocracia
# 1416 -- merkel
# 1417 -- meterle
# 1418 -- meterlo
# 1419 -- metio
# 1420 -- microbio
# 1421 -- microfono
# 1422 -- mientan
# 1423 -- mierd
# 1424 -- mierdaaa
# 1425 -- milag
# 1426 -- mile
# 1427 -- milei
# 1428 -- milen
# 1429 -- milicos
# 1430 -- milit
# 1431 -- militan
# 1432 -- militando
# 1433 -- millonaria
# 1434 -- millonarios
# 1435 -- minima
# 1436 -- minimo
# 1437 -- minoria
# 1438 -- mintio
# 1439 -- mirta
# 1440 -- miso
# 1441 -- mita
# 1442 -- mmmm
# 1443 -- modera
# 1444 -- mogol
# 1445 -- montonero
# 1446 -- montoneros
# 1447 -- morite
# 1448 -- motochorros
# 1449 -- movilizacion
# 1450 -- moy
# 1451 -- moyano
# 1452 -- muchis
# 1453 -- muchisimo
# 1454 -- muchisimos
# 1455 -- mueca
# 1456 -- mug
# 1457 -- mugr
# 1458 -- mugre
# 1459 -- mugrientos
# 1460 -- mugros
# 1461 -- multip
# 1462 -- mune
# 1463 -- muneco
# 1464 -- murciela
# 1465 -- murcielago
# 1466 -- murcielagos
# 1467 -- murio
# 1468 -- muuu
# 1469 -- naaa
# 1470 -- nabo
# 1471 -- nac
# 1472 -- nacio
# 1473 -- nacion
# 1474 -- nadaaa
# 1475 -- naf
# 1476 -- nafta
# 1477 -- narcos
# 1478 -- narcotrafico
# 1479 -- naus
# 1480 -- nauseas
# 1481 -- nazion
# 1482 -- nefas
# 1483 -- nefasta
# 1484 -- nefasto
# 1485 -- nefastos
# 1486 -- negocia
# 1487 -- nenes
# 1488 -- neoli
# 1489 -- neoliber
# 1490 -- neoliberal
# 1491 -- nestor
# 1492 -- netf
# 1493 -- netflix
# 1494 -- neuronas
# 1495 -- news
# 1496 -- nino
# 1497 -- ninos
# 1498 -- nisman
# 1499 -- nomas
# 1500 -- nooo
# 1501 -- noqui
# 1502 -- noquis
# 1503 -- nose
# 1504 -- noticion
# 1505 -- novie
# 1506 -- nucle
# 1507 -- oba
# 1508 -- obe
# 1509 -- obelisco
# 1510 -- obli
# 1511 -- obligacion
# 1512 -- obligo
# 1513 -- obsecu
# 1514 -- obsesion
# 1515 -- occi
# 1516 -- ocultan
# 1517 -- ocupen
# 1518 -- ocurr
# 1519 -- ocurrio
# 1520 -- odiadores
# 1521 -- ofelia
# 1522 -- ogt
# 1523 -- oidos
# 1524 -- ojala
# 1525 -- ojete
# 1526 -- oleada
# 1527 -- oli
# 1528 -- oligar
# 1529 -- oligarca
# 1530 -- oligarcas
# 1531 -- oligarquia
# 1532 -- olivos
# 1533 -- olvi
# 1534 -- olvidate
# 1535 -- omb
# 1536 -- ombligo
# 1537 -- oni
# 1538 -- opcion
# 1539 -- opere
# 1540 -- opereta
# 1541 -- opinan
# 1542 -- opinando
# 1543 -- opinar
# 1544 -- opine
# 1545 -- opinion
# 1546 -- oportunista
# 1547 -- oposicion
# 1548 -- oracion
# 1549 -- ordin
# 1550 -- organizacion
# 1551 -- organizarse
# 1552 -- orgu
# 1553 -- osde
# 1554 -- osea
# 1555 -- ota
# 1556 -- otamendi
# 1557 -- ovarios
# 1558 -- pade
# 1559 -- pagaran
# 1560 -- pagina
# 1561 -- paises
# 1562 -- pajero
# 1563 -- pajeros
# 1564 -- pami
# 1565 -- pande
# 1566 -- pandemias
# 1567 -- panico
# 1568 -- panqueque
# 1569 -- panuelos
# 1570 -- panza
# 1571 -- paraguayo
# 1572 -- paraguayos
# 1573 -- paraiso
# 1574 -- parasito
# 1575 -- parasitos
# 1576 -- paredon
# 1577 -- pario
# 1578 -- parri
# 1579 -- pasaria
# 1580 -- pasion
# 1581 -- pasquin
# 1582 -- patetica
# 1583 -- patetico
# 1584 -- pateticos
# 1585 -- patolo
# 1586 -- patriarcado
# 1587 -- pauta
# 1588 -- pava
# 1589 -- pavada
# 1590 -- pavadas
# 1591 -- payasa
# 1592 -- payasada
# 1593 -- pba
# 1594 -- pcia
# 1595 -- pedile
# 1596 -- pedof
# 1597 -- pedofilo
# 1598 -- pedofilos
# 1599 -- pedor
# 1600 -- pedorra
# 1601 -- pedorro
# 1602 -- pedos
# 1603 -- pego
# 1604 -- pelado
# 1605 -- pelic
# 1606 -- peliculas
# 1607 -- pelotu
# 1608 -- pelotuda
# 1609 -- pelotudas
# 1610 -- pelotude
# 1611 -- pelotudeces
# 1612 -- pelotudes
# 1613 -- pelotudez
# 1614 -- pelotudo
# 1615 -- pelotudooo
# 1616 -- pelotudos
# 1617 -- pendeja
# 1618 -- pensa
# 1619 -- pensas
# 1620 -- pensativa
# 1621 -- pension
# 1622 -- pequ
# 1623 -- pequeno
# 1624 -- perdio
# 1625 -- perdonan
# 1626 -- perjud
# 1627 -- peron
# 1628 -- peroncha
# 1629 -- peroncho
# 1630 -- peronchos
# 1631 -- peronia
# 1632 -- peronismo
# 1633 -- peronista
# 1634 -- peronistas
# 1635 -- peruanos
# 1636 -- perversa
# 1637 -- perverso
# 1638 -- pestes
# 1639 -- petrol
# 1640 -- petroleo
# 1641 -- pfiz
# 1642 -- pfizer
# 1643 -- piba
# 1644 -- pibe
# 1645 -- pibes
# 1646 -- pibis
# 1647 -- pidan
# 1648 -- pidio
# 1649 -- pija
# 1650 -- pinas
# 1651 -- pintarse
# 1652 -- pique
# 1653 -- piqueteros
# 1654 -- pisar
# 1655 -- pj
# 1656 -- planero
# 1657 -- planeros
# 1658 -- plastico
# 1659 -- plo
# 1660 -- poblacion
# 1661 -- pobrecita
# 1662 -- pobrecito
# 1663 -- pobrecitos
# 1664 -- podes
# 1665 -- podian
# 1666 -- podra
# 1667 -- podran
# 1668 -- podri
# 1669 -- podrian
# 1670 -- podrida
# 1671 -- podrido
# 1672 -- polem
# 1673 -- polemica
# 1674 -- polemico
# 1675 -- polenta
# 1676 -- policias
# 1677 -- polit
# 1678 -- politi
# 1679 -- politicamente
# 1680 -- politicas
# 1681 -- politico
# 1682 -- politicos
# 1683 -- pondria
# 1684 -- ponele
# 1685 -- ponete
# 1686 -- ponganse
# 1687 -- popu
# 1688 -- popul
# 1689 -- populismo
# 1690 -- populista
# 1691 -- populistas
# 1692 -- porfa
# 1693 -- poro
# 1694 -- poron
# 1695 -- poronga
# 1696 -- porota
# 1697 -- porq
# 1698 -- porqu
# 1699 -- porqueria
# 1700 -- porquerias
# 1701 -- portacion
# 1702 -- porten
# 1703 -- portenos
# 1704 -- posta
# 1705 -- pq
# 1706 -- prefier
# 1707 -- preguntale
# 1708 -- pregunten
# 1709 -- preocupacion
# 1710 -- prepo
# 1711 -- presi
# 1712 -- prestamo
# 1713 -- princi
# 1714 -- privile
# 1715 -- privilegia
# 1716 -- proba
# 1717 -- procer
# 1718 -- produccion
# 1719 -- progre
# 1720 -- proh
# 1721 -- prometio
# 1722 -- propagan
# 1723 -- proposito
# 1724 -- prosti
# 1725 -- prostibu
# 1726 -- prostibulos
# 1727 -- proteccion
# 1728 -- protoc
# 1729 -- proxima
# 1730 -- proximo
# 1731 -- psicopa
# 1732 -- psicopata
# 1733 -- psiquiatr
# 1734 -- psiquiatrica
# 1735 -- psiquiatrico
# 1736 -- publicas
# 1737 -- publicos
# 1738 -- pucha
# 1739 -- pudr
# 1740 -- pudran
# 1741 -- pudrir
# 1742 -- pumas
# 1743 -- puno
# 1744 -- punteros
# 1745 -- put
# 1746 -- pute
# 1747 -- puterio
# 1748 -- putin
# 1749 -- qe
# 1750 -- qep
# 1751 -- qepd
# 1752 -- queb
# 1753 -- quedense
# 1754 -- queee
# 1755 -- quejan
# 1756 -- quejen
# 1757 -- queres
# 1758 -- querian
# 1759 -- quilmes
# 1760 -- quilo
# 1761 -- quilomb
# 1762 -- quilombo
# 1763 -- quiza
# 1764 -- racis
# 1765 -- rajar
# 1766 -- rapida
# 1767 -- rascan
# 1768 -- rating
# 1769 -- rebelion
# 1770 -- recibio
# 1771 -- recien
# 1772 -- recla
# 1773 -- recol
# 1774 -- recoleta
# 1775 -- recomen
# 1776 -- recontra
# 1777 -- recuperacion
# 1778 -- reflexion
# 1779 -- regalan
# 1780 -- regalando
# 1781 -- regalar
# 1782 -- regimen
# 1783 -- region
# 1784 -- reit
# 1785 -- rejun
# 1786 -- religion
# 1787 -- reme
# 1788 -- remil
# 1789 -- renuncie
# 1790 -- renuncien
# 1791 -- repa
# 1792 -- repri
# 1793 -- reprodu
# 1794 -- republ
# 1795 -- republica
# 1796 -- repudio
# 1797 -- resenti
# 1798 -- resentida
# 1799 -- resentido
# 1800 -- resentidos
# 1801 -- resentimiento
# 1802 -- resf
# 1803 -- resop
# 1804 -- resoplando
# 1805 -- respirador
# 1806 -- respiradores
# 1807 -- responsab
# 1808 -- restr
# 1809 -- resu
# 1810 -- retrogra
# 1811 -- reunion
# 1812 -- reventa
# 1813 -- reveren
# 1814 -- reves
# 1815 -- revolv
# 1816 -- revolviendose
# 1817 -- rial
# 1818 -- ricar
# 1819 -- ridic
# 1820 -- ridicula
# 1821 -- ridiculo
# 1822 -- ridiculos
# 1823 -- rien
# 1824 -- rios
# 1825 -- robarle
# 1826 -- roben
# 1827 -- rodri
# 1828 -- rompan
# 1829 -- rompio
# 1830 -- ronoso
# 1831 -- rosada
# 1832 -- rua
# 1833 -- rugb
# 1834 -- rugbiers
# 1835 -- runner
# 1836 -- runners
# 1837 -- sabiamos
# 1838 -- sabian
# 1839 -- sacarlos
# 1840 -- salame
# 1841 -- saldra
# 1842 -- sali
# 1843 -- salia
# 1844 -- salio
# 1845 -- salis
# 1846 -- saludando
# 1847 -- saluden
# 1848 -- sancion
# 1849 -- saqueos
# 1850 -- sarasa
# 1851 -- secua
# 1852 -- secuaces
# 1853 -- secun
# 1854 -- seee
# 1855 -- segui
# 1856 -- seguira
# 1857 -- seguiran
# 1858 -- seguis
# 1859 -- sele
# 1860 -- selector
# 1861 -- semb
# 1862 -- senal
# 1863 -- senil
# 1864 -- senora
# 1865 -- senores
# 1866 -- sensacion
# 1867 -- seran
# 1868 -- seras
# 1869 -- seriales
# 1870 -- serian
# 1871 -- servil
# 1872 -- sesion
# 1873 -- show
# 1874 -- siemp
# 1875 -- siguien
# 1876 -- siii
# 1877 -- simbolos
# 1878 -- simil
# 1879 -- simio
# 1880 -- simios
# 1881 -- sindicalista
# 1882 -- sindicalistas
# 1883 -- sindro
# 1884 -- sindrome
# 1885 -- sinto
# 1886 -- sintomas
# 1887 -- sinver
# 1888 -- sinverguenza
# 1889 -- sinverguenzas
# 1890 -- sion
# 1891 -- sirvio
# 1892 -- situacion
# 1893 -- soberania
# 1894 -- soberbia
# 1895 -- soberbio
# 1896 -- sobran
# 1897 -- sobrepre
# 1898 -- sobrevi
# 1899 -- solange
# 1900 -- solidario
# 1901 -- solidarios
# 1902 -- soltaron
# 1903 -- soluciona
# 1904 -- sonrientes
# 1905 -- sonro
# 1906 -- sonrojada
# 1907 -- soreta
# 1908 -- sorete
# 1909 -- soretes
# 1910 -- soros
# 1911 -- sospe
# 1912 -- sput
# 1913 -- sputnik
# 1914 -- subio
# 1915 -- sudamer
# 1916 -- sudamerica
# 1917 -- sueno
# 1918 -- suenos
# 1919 -- sufici
# 1920 -- sufri
# 1921 -- sumando
# 1922 -- sumen
# 1923 -- supports
# 1924 -- susana
# 1925 -- tampo
# 1926 -- tapabo
# 1927 -- tapada
# 1928 -- tapados
# 1929 -- tapitas
# 1930 -- tarada
# 1931 -- tarados
# 1932 -- tb
# 1933 -- tecnologia
# 1934 -- tendra
# 1935 -- tendran
# 1936 -- tendri
# 1937 -- tendria
# 1938 -- tendriamos
# 1939 -- tendrian
# 1940 -- tendrias
# 1941 -- tenes
# 1942 -- teniamos
# 1943 -- tenian
# 1944 -- term
# 1945 -- teste
# 1946 -- testeos
# 1947 -- teta
# 1948 -- tib
# 1949 -- tibio
# 1950 -- tibios
# 1951 -- tie
# 1952 -- tiemb
# 1953 -- tiemp
# 1954 -- tilin
# 1955 -- tilinga
# 1956 -- tinelli
# 1957 -- tipa
# 1958 -- tipica
# 1959 -- tipico
# 1960 -- tiraron
# 1961 -- tit
# 1962 -- titere
# 1963 -- titula
# 1964 -- titulo
# 1965 -- titulos
# 1966 -- tmb
# 1967 -- todes
# 1968 -- totalitario
# 1969 -- toxica
# 1970 -- trabas
# 1971 -- traduccion
# 1972 -- traid
# 1973 -- traidora
# 1974 -- transfor
# 1975 -- transito
# 1976 -- trascen
# 1977 -- travesti
# 1978 -- trol
# 1979 -- trola
# 1980 -- trolas
# 1981 -- trolls
# 1982 -- trolo
# 1983 -- trolos
# 1984 -- trompadas
# 1985 -- trucho
# 1986 -- truchos
# 1987 -- trump
# 1988 -- tucan
# 1989 -- tucuman
# 1990 -- tugo
# 1991 -- tupe
# 1992 -- tuv
# 1993 -- tw
# 1994 -- twit
# 1995 -- twitter
# 1996 -- uhh
# 1997 -- uhhh
# 1998 -- ultimos
# 1999 -- unicos
# 2000 -- urra
# 2001 -- urs
# 2002 -- ursula
# 2003 -- user
# 2004 -- usurpa
# 2005 -- usurpacion
# 2006 -- usurpadores
# 2007 -- usurpar
# 2008 -- utili
# 2009 -- uy
# 2010 -- vacio
# 2011 -- vacunar
# 2012 -- vacunarse
# 2013 -- vaga
# 2014 -- vagancia
# 2015 -- vagos
# 2016 -- vamo
# 2017 -- varados
# 2018 -- varon
# 2019 -- vayanse
# 2020 -- velorio
# 2021 -- vendan
# 2022 -- vendria
# 2023 -- venezolanos
# 2024 -- veni
# 2025 -- venia
# 2026 -- venian
# 2027 -- veran
# 2028 -- vereda
# 2029 -- vergonzos
# 2030 -- verguenza
# 2031 -- verna
# 2032 -- viajo
# 2033 -- viale
# 2034 -- vicentin
# 2035 -- vicep
# 2036 -- vicepres
# 2037 -- victi
# 2038 -- victimas
# 2039 -- victimi
# 2040 -- vide
# 2041 -- videla
# 2042 -- villeros
# 2043 -- violacion
# 2044 -- violador
# 2045 -- violadores
# 2046 -- violan
# 2047 -- violo
# 2048 -- viral
# 2049 -- virtu
# 2050 -- vivi
# 2051 -- vivia
# 2052 -- vivid
# 2053 -- vividora
# 2054 -- vivien
# 2055 -- vivis
# 2056 -- voca
# 2057 -- volve
# 2058 -- volvio
# 2059 -- vomit
# 2060 -- vomitando
# 2061 -- vota
# 2062 -- votamos
# 2063 -- votan
# 2064 -- votando
# 2065 -- votante
# 2066 -- votaron
# 2067 -- votaste
# 2068 -- vote
# 2069 -- voten
# 2070 -- we
# 2071 -- what
# 2072 -- whis
# 2073 -- whisky
# 2074 -- wow
# 2075 -- wtf
# 2076 -- wu
# 2077 -- wuhan
# 2078 -- xd
# 2079 -- xenofob
# 2080 -- xq
# 2081 -- yaaa
# 2082 -- yanina
# 2083 -- yank
# 2084 -- yankis
# 2085 -- yegua
# 2086 -- yer
# 2087 -- yerba
# 2088 -- zaf
# 2089 -- zaff
# 2090 -- zaffaroni
# 2091 -- zomb
# 2092 -- zombies
# 2093 -- zoom
# 2094 -- zurda
# 2095 -- zurdo
# 2096 -- zurdos
# 2097 -- ⊙
# 2098 -- │
# 2099 -- ◎

# %% [markdown]
# Ok, agreguemos sólo los que son alpha

# %%
add_tokens = [t for t in missing_tokens if t.isalnum() or t.startswith("##")]

len(add_tokens), len(missing_tokens)
# Out:
# (2089, 2099)

# %% [markdown]
# ## Agregar nuevos tokens

# %%
tokenizer.add_special_tokens({'additional_special_tokens': special_tokens})
tokenizer.add_tokens(add_tokens)
# Out:
# 2089

# %%
len(special_tokens) + len(add_tokens) + 31002
# Out:
# 33094

# %% [markdown]
# Bien

# %%
import os


os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# %%
import torch
from transformers import BertForMaskedLM


model = BertForMaskedLM.from_pretrained(model_name)
device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)

tokenizer.model_max_length = 256

model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(33094, 768)

# %%
def tokenize(batch):
    return tokenizer(batch['context'], batch['text'], padding='max_length', truncation=True)

batch_size = 16
eval_batch_size = 8

train_dataset = train_dataset.map(tokenize, batched=True, batch_size=batch_size)
dev_dataset = dev_dataset.map(tokenize, batched=True, batch_size=batch_size)
dev_dataset
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2277.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=570.0), HTML(value='')))
# Dataset({
#     features: ['APPEARANCE', 'CALLS', 'CLASS', 'CRIMINAL', 'DISABLED', 'HATEFUL', 'LGBTI', 'POLITICS', 'RACISM', 'WOMEN', 'attention_mask', 'context', 'id', 'input_ids', 'text', 'token_type_ids'],
#     num_rows: 9106
# })

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=True, mlm_probability=0.15
)

# %%
from transformers import Trainer, TrainingArguments

new_model_name = "beto-finetuned-context"

new_model_path = f"../models/{new_model_name}"

training_args = TrainingArguments(
    output_dir=new_model_path,
    overwrite_output_dir=True,
    num_train_epochs=5,
    evaluation_strategy="steps",
    eval_steps=500,
    # Smaller LR
    learning_rate=1e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=eval_batch_size,
    save_steps=1500,
    logging_steps=50,
    do_eval= True,
    save_total_limit=2,
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=dev_dataset,
)

# %%
trainer.train()
# Out:
# /home/jmperez/.local/share/virtualenvs/hatespeech-classification-n4GdOxTz/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:64: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='3001' max='5695' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3001/5695 1:48:24 < 1:37:23, 0.46 it/s, Epoch 2.63/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.848500</td>
#       <td>3.586415</td>
#       <td>345.770000</td>
#       <td>26.335000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>3.306400</td>
#       <td>3.058932</td>
#       <td>346.196500</td>
#       <td>26.303000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.926400</td>
#       <td>2.734172</td>
#       <td>345.813000</td>
#       <td>26.332000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.724700</td>
#       <td>2.506068</td>
#       <td>345.919800</td>
#       <td>26.324000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.507600</td>
#       <td>2.366964</td>
#       <td>345.998100</td>
#       <td>26.318000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.440200</td>
#       <td>2.251052</td>
#       <td>345.712100</td>
#       <td>26.340000</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/jmperez/.local/share/virtualenvs/hatespeech-classification-n4GdOxTz/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:64: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/share/virtualenvs/hatespeech-classification-n4GdOxTz/lib/python3.8/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     371             with _open_zipfile_writer(opened_file) as opened_zipfile:
# --> 372                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     373                 return
#
# ~/.local/share/virtualenvs/hatespeech-classification-n4GdOxTz/lib/python3.8/site-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     492             buf_value = buf.getvalue()
# --> 493             zip_file.write_record(name, buf_value, len(buf_value))
#     494
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-3435b262f1ae> in <module>
# ----> 1 trainer.train()
#
# ~/.local/share/virtualenvs/hatespeech-classification-n4GdOxTz/lib/python3.8/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, **kwargs)
#    1103                     self.control = self.callback_handler.on_step_end(self.args, self.state, self.control)
#    1104
# -> 1105                     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch)
#    1106
#    1107                 if self.control.should_epoch_stop or self.control.should_training_stop:
#
# ~/.local/share/virtualenvs/hatespeech-classification-n4GdOxTz/lib/python3.8/site-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, model, trial, epoch)
#    1200
#    1201         if self.control.should_save:
# -> 1202             self._save_checkpoint(model, trial, metrics=metrics)
#    1203             self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#    1204
#
# ~/.local/share/virtualenvs/hatespeech-classification-n4GdOxTz/lib/python3.8/site-packages/transformers/trainer.py in _save_checkpoint(self, model, trial, metrics)
#    1241         elif self.is_world_process_zero() and not self.deepspeed:
#    1242             # deepspeed.save_checkpoint above saves model/optim/sched
# -> 1243             torch.save(self.optimizer.state_dict(), os.path.join(output_dir, "optimizer.pt"))
#    1244             with warnings.catch_warnings(record=True) as caught_warnings:
#    1245                 torch.save(self.lr_scheduler.state_dict(), os.path.join(output_dir, "scheduler.pt"))
#
# ~/.local/share/virtualenvs/hatespeech-classification-n4GdOxTz/lib/python3.8/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     371             with _open_zipfile_writer(opened_file) as opened_zipfile:
#     372                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
# --> 373                 return
#     374         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#     375
#
# ~/.local/share/virtualenvs/hatespeech-classification-n4GdOxTz/lib/python3.8/site-packages/torch/serialization.py in __exit__(self, *args)
#     257
#     258     def __exit__(self, *args) -> None:
# --> 259         self.file_like.write_end_of_file()
#     260         self.buffer.flush()
#     261
#
# RuntimeError: [enforce fail at inline_container.cc:274] . unexpected pos 740655808 vs 740655696

# %%
model.save_pretrained(new_model_path)
tokenizer.save_pretrained(new_model_path)
# Out:
# ('../models/beto-finetuned-context/tokenizer_config.json',
#  '../models/beto-finetuned-context/special_tokens_map.json',
#  '../models/beto-finetuned-context/vocab.txt',
#  '../models/beto-finetuned-context/added_tokens.json')
